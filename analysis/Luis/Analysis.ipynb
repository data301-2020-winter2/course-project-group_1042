# %%
from project_functions import *
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = data_processing_rename("data/Medical_Cost.csv")
df.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region  Medical Costs
# 0   19  female  27.900         0    yes  southwest    16884.92400
# 1   18    male  33.770         1     no  southeast     1725.55230
# 2   28    male  33.000         3     no  southeast     4449.46200
# 3   33    male  22.705         0     no  northwest    21984.47061
# 4   32    male  28.880         0     no  northwest     3866.85520

# %%
# Creating dataframes with different sorts for easy loc functions
from project_functions import *
df_age = data_processing_age_sort("data/Medical_Cost.csv")
df_region = data_processing_region_sort("data/Medical_Cost.csv")
df_children = data_processing_children_sort("data/Medical_Cost.csv")
df_smoker = data_processing_smoker_sort("data/Medical_Cost.csv")
df_sex = data_processing_sex_sort("data/Medical_Cost.csv")

# %%
# Obtaining values for the original dataset
print('Original Dataset')
print('Count:', df['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (df['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (df['Medical Costs'].sum()))

# Obtaining values for smokers
temp = df_smoker.drop(df_smoker[df_smoker.Smoker == 'no'].index).reset_index(drop = True)
print('\nOnly Smokers')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for non-smokers
temp = df_smoker.drop(df_smoker[df_smoker.Smoker == 'yes'].index).reset_index(drop = True)
print('\nOnly Non Smokers')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for people with children
temp = df_children.drop(df_children[df_children.Children > 0].index).reset_index(drop = True)
print('\nOnly People With Children')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for people without children
temp = df_children.drop(df_children[df_children.Children == 0].index).reset_index(drop = True)
print('\nOnly People With No Children')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for men
temp = df_children.drop(df_sex[df_sex.Sex == 'female'].index).reset_index(drop = True)
print('\nOnly Men')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for women
temp = df_children.drop(df_sex[df_sex.Sex == 'male'].index).reset_index(drop = True)
print('\nOnly Women')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for people in the northeast
temp = df_region.drop(df_region[df_region.Region != 'northeast'].index).reset_index(drop = True)
print('\nOnly People In The Northeast')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for people in the northwest
temp = df_region.drop(df_region[df_region.Region != 'northwest'].index).reset_index(drop = True)
print('\nOnly People In The Northwest')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for people in the southeast
temp = df_region.drop(df_region[df_region.Region != 'southeast'].index).reset_index(drop = True)
print('\nOnly People In The Southeast')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))

# Obtaining values for people in the southwest
temp = df_region.drop(df_region[df_region.Region != 'southwest'].index).reset_index(drop = True)
print('\nOnly People In The Southwest')
print('Count:', temp['Medical Costs'].count(), 'entries')
print('Mean: %.2f dollars' % (temp['Medical Costs'].mean()))
print('Sum: %.2f dollars' % (temp['Medical Costs'].sum()))
# Out:
# Original Dataset
# Count: 1338 entries
# Mean: 13270.42 dollars
# Sum: 17755824.99 dollars
#
# Only Smokers
# Count: 274 entries
# Mean: 32050.23 dollars
# Sum: 8781763.52 dollars
#
# Only Non Smokers
# Count: 1064 entries
# Mean: 8434.27 dollars
# Sum: 8974061.47 dollars
#
# Only People With Children
# Count: 574 entries
# Mean: 12365.98 dollars
# Sum: 7098070.00 dollars
#
# Only People With No Children
# Count: 764 entries
# Mean: 13949.94 dollars
# Sum: 10657755.00 dollars
#
# Only Men
# Count: 676 entries
# Mean: 14167.40 dollars
# Sum: 9577160.56 dollars
#
# Only Women
# Count: 662 entries
# Mean: 12354.48 dollars
# Sum: 8178664.43 dollars
#
# Only People In The Northeast
# Count: 324 entries
# Mean: 13406.38 dollars
# Sum: 4343668.58 dollars
#
# Only People In The Northwest
# Count: 325 entries
# Mean: 12417.58 dollars
# Sum: 4035712.00 dollars
#
# Only People In The Southeast
# Count: 364 entries
# Mean: 14735.41 dollars
# Sum: 5363689.76 dollars
#
# ...

# %%
sns.stripplot(x = 'Smoker', y = 'Medical Costs', data = df_smoker)
# Smoking increases costs
# Out:
# <AxesSubplot:xlabel='Smoker', ylabel='Medical Costs'>

# %%
sns.catplot(x = 'Children', y = 'Medical Costs', data = df_children)
# Children decrease costs. Unexpected

# %%
sns.stripplot(x = 'Sex', y = 'Medical Costs', data = df_sex)
# Sex is not a factor
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Medical Costs'>

# %%
sns.stripplot(x = 'Region', y = 'Medical Costs', data = df_region)
# Region is mostly not a factor
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Medical Costs'>

# %%
sns.relplot(x = 'BMI', y = 'Medical Costs', data = df)
# People with higher BMI show biggest figures

# %%
sns.displot(x = 'Medical Costs', data = df)
# Lower medical costs are most common
