# %% [markdown]
# ---
# This is an example of using the horizontal line

# %% [markdown]
# **Joel** Joel

# %% [markdown]
# 1. First Thing
# 2. Second Thing
# 3. Third Thing

# %% [markdown]
# [cbc](https:/cbc.ca)

# %% [markdown]
# > Hi my name is Joel

# %% [markdown]
# ![Screen Shot 2021-02-25 at 5.14.27 PM.png](attachment:0674e8bc-0033-4579-9b4b-2414d67f75ab.png)

# %% [markdown]
# * This
# * is
# * an unorder list

# %% [markdown]
# *Italic text*  Non Italic Text

# %% [markdown]
# # Header
# This is how to do a header
# The number of #'s change the size of the header (more means smaller)
